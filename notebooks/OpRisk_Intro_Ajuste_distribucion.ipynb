# %%
# !git clone https://github.com/franciscogarate/utils_ucm
# Out:
# Cloning into 'utils_ucm'...
# remote: Enumerating objects: 212, done.
# remote: Counting objects: 100% (212/212), done.
# remote: Compressing objects: 100% (166/166), done.
# remote: Total 212 (delta 111), reused 119 (delta 43), pack-reused 0 (from 0)
# Receiving objects: 100% (212/212), 1.44 MiB | 7.01 MiB/s, done.
# Resolving deltas: 100% (111/111), done.

# %%
# %%bash
# cd utils_ucm
# make copia_siniestros
# Out:
# cd ./data && cp siniestros.csv ../../

# %%
import pandas as pd
import scipy.stats as stdfg =

# %%
df = pd.read_csv('siniestros.csv', sep=';', header=0)
df.head()
# Out:
#    Siniestro  Poliza     Fec_ocu     Fec_com    Fec_pago  Importe
# 0          1   31082  12-09-2021  21-09-2021  03-07-2022       83
# 1          2   61275  20-11-2022  03-01-2023  02-02-2023       71
# 2          3   72257  10-06-2018  25-06-2018  15-07-2018      115
# 3          4   73111  17-09-2018  05-10-2018  20-09-2023       67
# 4          5   84755  30-06-2022  12-07-2022  30-09-2022      122

# %%
df.hist(column='Importe', bins=40)
# Out:
# array([[<Axes: title={'center': 'Importe'}>]], dtype=object)

# %%
media, desviacion = st.norm.fit(df['Importe'])
print(media)
print(desviacion)
# Out:
# 99.4229
# 20.510208570124295

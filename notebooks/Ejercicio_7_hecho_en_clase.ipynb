# %%
# !git clone https://github.com/franciscogarate/utils_ucm
# Out:
# Cloning into 'utils_ucm'...
# remote: Enumerating objects: 151, done.
# remote: Counting objects: 100% (151/151), done.
# remote: Compressing objects: 100% (110/110), done.
# remote: Total 151 (delta 70), reused 106 (delta 38), pack-reused 0 (from 0)
# Receiving objects: 100% (151/151), 370.56 KiB | 1.46 MiB/s, done.
# Resolving deltas: 100% (70/70), done.

# %%
import pandas as pd
import numpy as np
from utils_ucm import *

# %%
pasem2020
# Out:
#      PASEM2020_General_F_2ord  PASEM2020_General_M_2ord  PASEM2020_Rel_F_1ord  \
# 0                    1.591521                  1.818519              1.753657
# 1                    0.113517                  0.130901              0.125081
# 2                    0.093457                  0.109293              0.102978
# 3                    0.075466                  0.089877              0.083154
# 4                    0.060768                  0.073906              0.066959
# ..                        ...                       ...                   ...
# 116               1000.000000               1000.000000           1000.000000
# 117               1000.000000               1000.000000           1000.000000
# 118               1000.000000               1000.000000           1000.000000
# 119               1000.000000               1000.000000           1000.000000
# 120               1000.000000               1000.000000           1000.000000
#
# ...

# %%
lx_unisex
# Out:
#               LX
# 0    100000.0000
# 1     99002.7280
# 2     98002.9236
# 3     97003.0858
# 4     96003.2180
# ..           ...
# 107     614.7622
# 108     470.9027
# 109     380.1981
# 110     331.2711
# 111       0.0000
#
# [112 rows x 1 columns]

# %%
def obtener_lx(edad):
  return lx_unisex['LX'][edad]

# %%
obtener_lx(20)
# Out:
# 80005.4365

# %%
edad = 50
fval = '2024-12-31'

# %%
fechas = pd.date_range(start='2024-12-31', periods=len(lx_unisex)-edad, freq='YE')

# %%
df = pd.DataFrame(fechas, columns=['fecha'])
df.head(3)
# Out:
#        fecha
# 0 2024-12-31
# 1 2025-12-31
# 2 2026-12-31

# %%
df['edad'] = edad + df.index
df.head(3)
# Out:
#        fecha  edad
# 0 2024-12-31    50
# 1 2025-12-31    51
# 2 2026-12-31    52

# %%
df['lx'] = df['edad'].apply(obtener_lx)
df.head(3)
# Out:
#        fecha  edad          lx
# 0 2024-12-31    50  50023.8490
# 1 2025-12-31    51  49026.3009
# 2 2026-12-31    52  48029.0041

# %%
df['qx'] = df['lx'].diff(-1).fillna(0) / df['lx'][0]
df
# Out:
#         fecha  edad          lx        qx
# 0  2024-12-31    50  50023.8490  0.019941
# 1  2025-12-31    51  49026.3009  0.019936
# 2  2026-12-31    52  48029.0041  0.019931
# 3  2027-12-31    53  47031.9733  0.019926
# 4  2028-12-31    54  46035.2209  0.019920
# ..        ...   ...         ...       ...
# 57 2081-12-31   107    614.7622  0.002876
# 58 2082-12-31   108    470.9027  0.001813
# 59 2083-12-31   109    380.1981  0.000978
# 60 2084-12-31   110    331.2711  0.006622
# 61 2085-12-31   111      0.0000  0.000000
#
# [62 rows x 4 columns]

# %%
df['capital'] = 5000
df['pagos_esperados'] = df.capital * df.qx
df['factor_dto'] = 1/ (1+ 2.18/100) ** (df.index)
df.head()
# Out:
#        fecha  edad          lx        qx  capital  pagos_esperados  factor_dto
# 0 2024-12-31    50  50023.8490  0.019941     5000        99.707252    1.000000
# 1 2025-12-31    51  49026.3009  0.019936     5000        99.682134    0.978665
# 2 2026-12-31    52  48029.0041  0.019931     5000        99.655546    0.957785
# 3 2027-12-31    53  47031.9733  0.019926     5000        99.627720    0.937351
# 4 2028-12-31    54  46035.2209  0.019920     5000        99.598673    0.917353

# %%
df.pagos_esperados @ df.factor_dto
# Out:
# 3054.9484607764757

# %%
sum(df.pagos_esperados)
# Out:
# 5000.000000000002

# %%
df.to_excel('Ejercicio_7_PM_Decesos.xlsx')

# %% [markdown]
# ### Réplica hecha con signos de conmutación (en desuso)
# Instalo previamente la librería **pyliferisk**

# %%
# !pip install pyliferisk

# %%
# %%bash
# cp ../utils_ucm/tablas.py
# git pull
# Out:
# Already up to date.

# %%
from utils_ucm.tablas import lx_decesos_m
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from utils_ucm.tablas import lx_decesos_m
#
# ModuleNotFoundError: No module named 'utils_ucm'

# %%
from pyliferisk import MortalityTable, Actuarial, Ax
from pyliferisk.mortalitytables import INM05, PASEM2020_Decesos_M_1ord

# %%
#lx_unisex = lx_unisex['LX'].tolist()
#mt = MortalityTable(lx=lx_unisex)
mt = Actuarial(nt=PASEM2020_Decesos_M_1ord, i=0.0218)
x = 50
c = 5000
Ax(mt,x) * c
# Out:
# 2608.9019307383955

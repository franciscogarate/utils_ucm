# %%
# !git clone https://github.com/franciscogarate/utils_ucm
# Out:
# Cloning into 'utils_ucm'...
# remote: Enumerating objects: 159, done.
# remote: Counting objects: 100% (159/159), done.
# remote: Compressing objects: 100% (118/118), done.
# remote: Total 159 (delta 76), reused 105 (delta 38), pack-reused 0 (from 0)
# Receiving objects: 100% (159/159), 381.54 KiB | 1.33 MiB/s, done.
# Resolving deltas: 100% (76/76), done.

# %%
import pandas as pd
import numpy as np
from utils_ucm import lx_unisex

# %%
def obtener_lx(edad):
  return lx_unisex['LX'][edad]

# %%
obtener_lx(20)
# Out:
# 80005.4365

# %%
edad = 50
fval = '2024-12-31'

# %%
fechas = pd.date_range(start='2024-12-31', periods=len(lx_unisex)-edad, freq='YE')

# %%
df = pd.DataFrame(fechas, columns=['fecha'])
df.head(3)
# Out:
#        fecha
# 0 2024-12-31
# 1 2025-12-31
# 2 2026-12-31

# %%
df['edad'] = edad + df.index
df.head(3)
# Out:
#        fecha  edad
# 0 2024-12-31    50
# 1 2025-12-31    51
# 2 2026-12-31    52

# %%
df['lx'] = df['edad'].apply(obtener_lx)
df.head(3)
# Out:
#        fecha  edad          lx
# 0 2024-12-31    50  50023.8490
# 1 2025-12-31    51  49026.3009
# 2 2026-12-31    52  48029.0041

# %%
df['qx'] = df['lx'].diff(-1).fillna(0) / df['lx'][0]
df
# Out:
#         fecha  edad          lx  capital        qx
# 0  2024-12-31    50  50023.8490     5000  0.019941
# 1  2025-12-31    51  49026.3009     5000  0.019936
# 2  2026-12-31    52  48029.0041     5000  0.019931
# 3  2027-12-31    53  47031.9733     5000  0.019926
# 4  2028-12-31    54  46035.2209     5000  0.019920
# ..        ...   ...         ...      ...       ...
# 57 2081-12-31   107    614.7622     5000  0.002876
# 58 2082-12-31   108    470.9027     5000  0.001813
# 59 2083-12-31   109    380.1981     5000  0.000978
# 60 2084-12-31   110    331.2711     5000  0.006622
# 61 2085-12-31   111      0.0000     5000  0.000000
#
# [62 rows x 5 columns]

# %%
df['capital'] = 5000
df['pagos_esperados'] = df.capital * df.qx
df['factor_dto'] = 1/ (1+ 2.18/100) ** (df.index)
df.head()
# Out:
#        fecha  edad          lx  capital        qx  pagos_esperados  factor_dto
# 0 2024-12-31    50  50023.8490     5000  0.019941        99.707252    1.000000
# 1 2025-12-31    51  49026.3009     5000  0.019936        99.682134    0.978665
# 2 2026-12-31    52  48029.0041     5000  0.019931        99.655546    0.957785
# 3 2027-12-31    53  47031.9733     5000  0.019926        99.627720    0.937351
# 4 2028-12-31    54  46035.2209     5000  0.019920        99.598673    0.917353

# %%
df.pagos_esperados @ df.factor_dto
# Out:
# 3054.9484607764757

# %%
sum(df.pagos_esperados)
# Out:
# 5000.000000000002

# %%
df.to_excel('Ejercicio_7_PM_Decesos.xlsx')
